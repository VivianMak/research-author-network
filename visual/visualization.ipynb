# %%
# Main Function
import os
import sys
directory_path = os.path.abspath(os.path.join('..', 'src'))
if directory_path not in sys.path:
    sys.path.append(directory_path)

import numpy as np
import main

main.main()
# Out:
# ----ADDING NEW AUTHOR-----
# ----ADDING NEW AUTHOR-----
# ----ADDING NEW AUTHOR-----
# Showing final collboration adjacency matrix...
#     vp  bm  rw
# vp   0   1   1
# bm   1   0   0
# rw   1   0   0
# the neighbors of bm are [('vp', 1)]
# Shortest path: ['vp', 'rw']
